# %%
# import required packages
import pandas as pd
import os
import pickle
import sys
pd.options.display.width=None
pd.options.display.max_columns=None


if sys.version_info >= (3, 6):
    from zipfile import ZipFile as zipfile
else:
    import zipfile36 as zipfile
    
url = "https://unearthed-exploresa.s3-ap-southeast-2.amazonaws.com/Unearthed_5_SARIG_Data_Package.zip" 
# enter the directory to save data
data_loc = 'D:/GitFolder/WorkBench/exploreSA-Gawler/data'
file_name = 'Unearthed_5_SARIG_Data_Package.zip'

if os.path.isfile(os.path.join(data_loc, file_name)):
    print ("File exist")
    pass
else:
    # open and save the zip file onto computer
    url = urlopen(URL)
    output = open('Unearthed_5_SARIG_Data_Package.zip', 'wb')    # note the flag:  "wb"        
    output.write(url.read())
    output.close()
    
files_in_dataset = []
file_name = 'Unearthed_5_SARIG_Data_Package.zip'
for file in zipfile(os.path.join(data_loc, file_name),'r').filelist:
    files_in_dataset.append(file.filename)
    
files_in_dataset
# Out:
# File exist
# ['SARIG_Data_Package/sarig_dh_core_exp.csv',
#  'SARIG_Data_Package/sarig_dh_details_exp.csv',
#  'SARIG_Data_Package/sarig_dh_litho_exp.csv',
#  'SARIG_Data_Package/sarig_dh_petrophys_exp.csv',
#  'SARIG_Data_Package/sarig_dh_reference_exp.csv',
#  'SARIG_Data_Package/sarig_dh_strat_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_litho_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_note_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_struct_exp.csv',
#  'SARIG_Data_Package/sarig_md_commodity_exp.csv',
#  'SARIG_Data_Package/sarig_md_details_exp.csv',
#  'SARIG_Data_Package/sarig_md_mineralogy_exp.csv',
#  'SARIG_Data_Package/sarig_md_reference_exp.csv',
#  'SARIG_Data_Package/sarig_md_zone_hr_lith_exp.csv',
#  'SARIG_Data_Package/sarig_md_zone_lith_exp.csv',
#  'SARIG_Data_Package/sarig_rs_biostr_analys_exp.csv',
#  'SARIG_Data_Package/sarig_rs_biostr_results_exp.csv',
#  'SARIG_Data_Package/sarig_rs_chem_exp.csv',
#  'SARIG_Data_Package/sarig_rs_chem_isotope_exp.csv',
#  'SARIG_Data_Package/sarig_rs_details_exp.csv',
#  'SARIG_Data_Package/sarig_rs_geochron_ages_exp.csv',
#  'SARIG_Data_Package/sarig_rs_geochron_reslt_exp.csv',
#  'SARIG_Data_Package/sarig_rs_petrology_exp.csv',
#  'SARIG_Data_Package/sarig_rs_reference_exp.csv',
#  'SARIG_Data_Package/vocabulary_codes_descriptions/',
#  'SARIG_Data_Package/vocabulary_codes_descriptions/chem_method_code_desc.csv',
#  'SARIG_Data_Package/vocabulary_codes_descriptions/lithology_code_desc.csv',
#  'SARIG_Data_Package/vocabulary_codes_descriptions/petro_type_code_desc.csv',
#  'SARIG_Data_Package/vocabulary_codes_descriptions/strat_unit_code_desc.csv',
#  'SARIG_Data_Package/vocabulary_codes_descriptions/Stratigraphic Unit Letter Code System - Explanation of the GIS Search Code and Map Symbol.pdf',
#  'SARIG_Data_Package/vocabulary_codes_descriptions/unit_code_desc.csv']

# %% [markdown]
# For this part of data cleaning, we will only use the following files:
#  - 'SARIG_Data_Package/sarig_fieldobs_exp.csv',
#  - 'SARIG_Data_Package/sarig_fieldobs_litho_exp.csv',
#  - 'SARIG_Data_Package/sarig_fieldobs_note_exp.csv',
#  - 'SARIG_Data_Package/sarig_fieldobs_struct_exp.csv'

# %%
# load the field observation summary data
sarig_fieldobs_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_fieldobs_exp.csv','r'), 
    sep=',', encoding='latin1')
sarig_fieldobs_exp.sample(5)
# Out:
#        SITE_NO       FIELD_ID      OBSERVER OBSERVATION_DATE FIELD_NOTE  \
# 71074  1807617        TRUS017   RUSAK, T.M.       03/09/2011          Y
# 87226   227251  0241202031060           NaN              NaN          N
# 73280   246063            NaN           NaN              NaN          N
# 5109    228654  0241201161113           NaN              NaN          N
# 50478   466014  2413B01081286  PREISS, W.V.              NaN          N
#
#       LITHOLOGY STRUCTURE ROCK_SAMPLE IMAGE LANDFORM_CODE LANDFORM_DESC  \
# 71074         Y         N           N     N           NaN           NaN
# 87226         Y         N           N     N           NaN           NaN
# 73280         N         Y           N     N           NaN           NaN
# 5109          Y         N           N     N           NaN           NaN
# 50478         Y         Y           N     N           NaN           NaN
#
#               MAP_250000       MAP_100000  MAP_50000  EASTING_GDA2020  \
# 71074     SG5310 ABMINGA      5645 Tieyon          1        375284.36
# 87226       SI5405 BURRA     6731 Caroona          4        336728.75
# 73280  SH5413 PARACHILNA  6535 Parachilna          1        259999.27
# 5109        SI5405 BURRA     6731 Caroona          1        354158.67
# 50478       SI5405 BURRA   6730 Florieton          3        319119.16
#
#        NORTHING_GDA2020  ZONE_GDA2020  LONGITUDE_GDA2020  LATITUDE_GDA2020  \
# 71074        7120028.57            53         133.753520        -26.033339
# 87226        6329471.42            54         139.249128        -33.161254
# 73280        6555089.48            54         138.483402        -31.113546
# 5109         6340155.59            54         139.437684        -33.067403
# 50478        6250195.31            54         139.044358        -33.873083
#
#        LONGITUDE_GDA94  LATITUDE_GDA94  HORIZ_ACCRCY_M  ELEVATION_M  \
# 71074       133.753511      -26.033325             5.0        495.3
# 87226       139.249118      -33.161240             NaN          NaN
# 73280       138.483392      -31.113532             NaN          NaN
# 5109        139.437674      -33.067390             NaN          NaN
# 50478       139.044348      -33.873068             NaN          NaN
#
#        VERT_ACCRCY_M SURVEY_METHOD_CODE                SURVEY_METHOD COMMENTS
# 71074            NaN              GPSSN  GPS Standalone Navigational      NaN
# 87226            NaN                NaN                          NaN      NaN
# 73280            NaN              AMGRD       Controlled AMG/MGA map      NaN
# 5109             NaN                NaN                          NaN      NaN
# 50478            NaN              PHOTO                    Air Photo      NaN

# %%
interested_fieldobs_exp = sarig_fieldobs_exp[['SITE_NO', 'FIELD_ID', 
       'LANDFORM_CODE', 'MAP_250000', 'MAP_100000', 'MAP_50000',
       'EASTING_GDA2020', 'NORTHING_GDA2020', 'ZONE_GDA2020',
       'LONGITUDE_GDA2020', 'LATITUDE_GDA2020', 'LONGITUDE_GDA94',
       'LATITUDE_GDA94', 'HORIZ_ACCRCY_M', 'ELEVATION_M', 'VERT_ACCRCY_M',
       'SURVEY_METHOD_CODE']]
interested_fieldobs_exp.sample(5)
# Out:
#        SITE_NO        FIELD_ID LANDFORM_CODE        MAP_250000  \
# 4764    217534  6226-iii/r7/33           NaN  SI5316 KINGSCOTE
# 84902   212449   0196200231011           NaN    SG5313 EVERARD
# 51852  1202255             NaN           NaN     SI5413 BARKER
# 49648   339800   2413B01321215           NaN      SI5405 BURRA
# 55691   231864   0072100951012           NaN  SG5212 WOODROFFE
#
#             MAP_100000  MAP_50000  EASTING_GDA2020  NORTHING_GDA2020  \
# 4764        6226 Borda          3        644606.58        6019267.52
# 84902  5543 Wantapella          4        314578.90        7012160.20
# 51852      6526 Jervis          4        230946.42        6041569.55
# 49648       6630 Clare          2        299424.71        6249734.51
# 55691    5045 Caroline          4        674018.56        7122752.39
#
#        ZONE_GDA2020  LONGITUDE_GDA2020  LATITUDE_GDA2020  LONGITUDE_GDA94  \
# 4764             53         136.603596        -35.960289       136.603586
# 84902            53         133.131313        -27.000284       133.131304
# 51852            54         138.025169        -35.733128       138.025159
# 49648            54         138.831448        -33.873673       138.831438
# 55691            52         130.738724        -26.003665       130.738715
#
#        LATITUDE_GDA94  HORIZ_ACCRCY_M  ELEVATION_M  VERT_ACCRCY_M  \
# 4764       -35.960275             NaN          NaN            NaN
# 84902      -27.000270             NaN          NaN            NaN
# 51852      -35.733114             NaN          NaN            NaN
# 49648      -33.873659             NaN          NaN            NaN
# 55691      -26.003651             NaN          NaN            NaN
#
#       SURVEY_METHOD_CODE
# 4764                 NaN
# 84902                NaN
# 51852                NaN
# 49648              GPSSN
# 55691              PHOTO

# %%
sarig_fieldobs_exp.columns
# Out:
# Index(['SITE_NO', 'FIELD_ID', 'OBSERVER', 'OBSERVATION_DATE', 'FIELD_NOTE',
#        'LITHOLOGY', 'STRUCTURE', 'ROCK_SAMPLE', 'IMAGE', 'LANDFORM_CODE',
#        'LANDFORM_DESC', 'MAP_250000', 'MAP_100000', 'MAP_50000',
#        'EASTING_GDA2020', 'NORTHING_GDA2020', 'ZONE_GDA2020',
#        'LONGITUDE_GDA2020', 'LATITUDE_GDA2020', 'LONGITUDE_GDA94',
#        'LATITUDE_GDA94', 'HORIZ_ACCRCY_M', 'ELEVATION_M', 'VERT_ACCRCY_M',
#        'SURVEY_METHOD_CODE', 'SURVEY_METHOD', 'COMMENTS'],
#       dtype='object')

# %%
sarig_fieldobs_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88221 entries, 0 to 88220
# Data columns (total 27 columns):
# SITE_NO               88221 non-null int64
# FIELD_ID              63727 non-null object
# OBSERVER              70938 non-null object
# OBSERVATION_DATE      19638 non-null object
# FIELD_NOTE            88221 non-null object
# LITHOLOGY             88221 non-null object
# STRUCTURE             88221 non-null object
# ROCK_SAMPLE           88221 non-null object
# IMAGE                 88221 non-null object
# LANDFORM_CODE         6208 non-null object
# LANDFORM_DESC         6208 non-null object
# MAP_250000            88221 non-null object
# MAP_100000            88221 non-null object
# MAP_50000             88221 non-null int64
# EASTING_GDA2020       88221 non-null float64
# NORTHING_GDA2020      88221 non-null float64
# ZONE_GDA2020          88221 non-null int64
# LONGITUDE_GDA2020     88221 non-null float64
# LATITUDE_GDA2020      88221 non-null float64
# LONGITUDE_GDA94       88221 non-null float64
# LATITUDE_GDA94        88221 non-null float64
# HORIZ_ACCRCY_M        17449 non-null float64
# ELEVATION_M           12067 non-null float64
# VERT_ACCRCY_M         10627 non-null float64
# SURVEY_METHOD_CODE    62798 non-null object
# SURVEY_METHOD         62798 non-null object
# COMMENTS              1407 non-null object
# dtypes: float64(9), int64(3), object(15)
# memory usage: 18.2+ MB

# %% [markdown]
# This data table includes the summary of the contents of the field observation dataset.

# %%
sarig_fieldobs_litho_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_fieldobs_litho_exp.csv','r'), 
    sep=',', encoding='latin1')
sarig_fieldobs_litho_exp['STRAT_UNIT_NO'] = sarig_fieldobs_litho_exp['STRAT_UNIT_NO'].astype('Int64')
sarig_fieldobs_litho_exp['OBSERVATION_DATE'] = pd.to_datetime(sarig_fieldobs_litho_exp['OBSERVATION_DATE'])
sarig_fieldobs_litho_exp.sample(5)
# Out:
#        SITE_NO  LITHOLOGY_NO MAP_SYMBOL GIS_CODE  STRAT_UNIT_NO STRAT_CONF  \
# 29870   284983         36079        Noq   N-wboq           3332        NaN
# 44538  1978518         70398        NaN      NaN            NaN        NaN
# 55597  1807806         63037        NaN      NaN            NaN        NaN
# 10897   228854         18265        NaN      NaN            NaN        NaN
# 6556    217684          9208        Elm   E-oklm           3813        NaN
#
#                 STRAT_NAME                                  STRAT_DESCRIPTION  \
# 29870       Blyth Dolomite  Sandstone; siltstone, grey; dolomite marble, g...
# 44538                  NaN                                                NaN
# 55597                  NaN                                                NaN
# 10897                  NaN                                                NaN
# 6556   Middleton Sandstone  Metasandstone, fine grained, grey, quartzose, ...
#
#       ROCK_GROUP_CODE                            ROCK_GROUP LITHO_CODE  \
# 29870             SCC  Sediment Chemical/Biogenic Carbonate       DLOM
# 44538            RPDC                  Duricrust Calcareous       DURC
# 55597              MG                   Metamorphic General       GNSS
# 10897               N                        No Information       XXXX
# 6556              SSA        Sediment Siliciclastic Arenite       SDST
#
#       LITHO_CONFIDENCE          LITHOLOGY_NAME            LITHO_MODIFIER  \
# 29870              NaN           Dolomite Rock                       NaN
# 44538              NaN  Duricrust (Calcareous)  in-situ, cellular, white
# 55597              NaN                  Gneiss                       NaN
# 10897              NaN          No Information                       NaN
# 6556               NaN               Sandstone                       NaN
#
#       LITHO_COMMENTS OBSERVATION_DATE  EASTING_GDA2020  NORTHING_GDA2020  \
# 29870            NaN       1998-07-31        273325.19        6253059.96
# 44538            NaN       2014-05-20        349389.70        7086961.15
# 55597            NaN       2011-09-09        386278.28        7103026.91
# 10897            NaN              NaT        356897.61        6324025.39
# 6556             NaN       1995-03-28        643800.79        6037558.30
#
#        ZONE_GDA2020  LONGITUDE_GDA2020  LATITUDE_GDA2020  LONGITUDE_GDA94  \
# 29870            54         138.550338        -33.838422       138.550328
# 44538            53         133.490939        -26.329358       133.490930
# 55597            53         133.861896        -26.187735       133.861887
# 10897            54         139.464484        -33.213212       139.464474
# 6556             53         136.591362        -35.795560       136.591352
#
#        LATITUDE_GDA94
# 29870      -33.838407
# 44538      -26.329344
# 55597      -26.187721
# 10897      -33.213198
# 6556       -35.795546

# %%
sarig_fieldobs_litho_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66212 entries, 0 to 66211
# Data columns (total 23 columns):
# SITE_NO              66212 non-null int64
# LITHOLOGY_NO         66212 non-null int64
# MAP_SYMBOL           46529 non-null object
# GIS_CODE             46529 non-null object
# STRAT_UNIT_NO        46587 non-null Int64
# STRAT_CONF           3710 non-null object
# STRAT_NAME           46587 non-null object
# STRAT_DESCRIPTION    46586 non-null object
# ROCK_GROUP_CODE      66212 non-null object
# ROCK_GROUP           66212 non-null object
# LITHO_CODE           66212 non-null object
# LITHO_CONFIDENCE     1114 non-null object
# LITHOLOGY_NAME       66212 non-null object
# LITHO_MODIFIER       30038 non-null object
# LITHO_COMMENTS       24365 non-null object
# OBSERVATION_DATE     41456 non-null datetime64[ns]
# EASTING_GDA2020      66212 non-null float64
# NORTHING_GDA2020     66212 non-null float64
# ZONE_GDA2020         66212 non-null int64
# LONGITUDE_GDA2020    66212 non-null float64
# LATITUDE_GDA2020     66212 non-null float64
# LONGITUDE_GDA94      66212 non-null float64
# LATITUDE_GDA94       66212 non-null float64
# dtypes: Int64(1), datetime64[ns](1), float64(6), int64(3), object(12)
# memory usage: 11.7+ MB

# %%
interested_fieldobs_litho_exp = sarig_fieldobs_litho_exp[
    ['SITE_NO', 'LITHOLOGY_NO', 'MAP_SYMBOL', 'GIS_CODE', 'STRAT_UNIT_NO', 
     'ROCK_GROUP_CODE', 'LITHO_CODE', 'LITHO_CONFIDENCE', 'LITHO_MODIFIER']]
interested_fieldobs_litho_exp.sample(5)
# Out:
#        SITE_NO  LITHOLOGY_NO MAP_SYMBOL    GIS_CODE  STRAT_UNIT_NO  \
# 2731    206701          2677        Kmo      K--rmo           4002
# 26581   271859         36357       Novs     N-wbovs           6226
# 16341   242270         25674       Qpe1  I---e---01           3177
# 217     130253          3932        NaN         NaN            NaN
# 28292   278016         32694        Ldc      L--d-c           6309
#
#       ROCK_GROUP_CODE LITHO_CODE LITHO_CONFIDENCE  \
# 2731              SSL       CLST              NaN
# 26581             MSS       MSLT              NaN
# 16341             SSA       SAND              NaN
# 217              RPDC       CALC              NaN
# 28292             IFI       GRNT              NaN
#
#                                       LITHO_MODIFIER
# 2731                                             NaN
# 26581                                            NaN
# 16341  f.g.; displays diffusely patchy soft calcrete
# 217                                              NaN
# 28292                                            NaN

# %%
sarig_fieldobs_note_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_fieldobs_note_exp.csv','r'), 
    sep=',', encoding='latin1')
# sarig_fieldobs_litho_exp['STRAT_UNIT_NO'] = sarig_fieldobs_litho_exp['STRAT_UNIT_NO'].astype('Int64')
# sarig_fieldobs_litho_exp['OBSERVATION_DATE'] = pd.to_datetime(sarig_fieldobs_litho_exp['OBSERVATION_DATE'])
sarig_fieldobs_note_exp.sample(5)
# Out:
#        SITE_NO  FIELD_NOTE_NO  \
# 14079   829385          18867
# 9316    129808          10936
# 20620  1970756          31764
# 18074  1842529          30437
# 13894   821382          18438
#
#                                              FIELD_NOTES OBSERVATION_DATE  \
# 14079          Survey peg - Rio Tinto?  606750E 7088200N       20/09/2004
# 9316   SAMPLE HAS THESE TWO ROCKS PLUS CHILLED MARGIN...              NaN
# 20620  Small kopje of massive, fine- to medium-graine...       26/08/2013
# 18074  Scattered, low, rubbley outcrop to the northwe...       29/09/2012
# 13894  more calcsilicate, folded plunging west  ?D3  ...       18/08/2004
#
#        EASTING_GDA2020  NORTHING_GDA2020  ZONE_GDA2020  LONGITUDE_GDA2020  \
# 14079        606916.66        7088361.53            52         130.071224
# 9316         766269.03        7086239.47            52         131.667282
# 20620        343951.37        7099203.27            53         133.437945
# 18074        312538.28        7069637.00            53         133.119311
# 13894        458909.71        6444897.48            54         140.564355
#
#        LATITUDE_GDA2020  LONGITUDE_GDA94  LATITUDE_GDA94
# 14079        -26.320656       130.071215      -26.320642
# 9316         -26.318995       131.667272      -26.318981
# 20620        -26.218275       133.437936      -26.218261
# 18074        -26.481338       133.119302      -26.481324
# 13894        -32.131571       140.564345      -32.131557

# %% [markdown]
# The FIELD_NOTES are words, which might require text mining, while these FIELD_NOTES does not give too much insight into the ores. So, we ignore this table.

# %%
sarig_fieldobs_struct_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_fieldobs_struct_exp.csv','r'), 
    sep=',', encoding='latin1')
# sarig_fieldobs_litho_exp['STRAT_UNIT_NO'] = sarig_fieldobs_litho_exp['STRAT_UNIT_NO'].astype('Int64')
# sarig_fieldobs_litho_exp['OBSERVATION_DATE'] = pd.to_datetime(sarig_fieldobs_litho_exp['OBSERVATION_DATE'])
sarig_fieldobs_struct_exp.sample(500)
# Out:
#        SITE_NO  LITHOLOGY_NO ROCK_GROUP_CODE                      ROCK_GROUP  \
# 21053   262887       49428.0             SSL   Sediment Siliciclastic Lutite
# 66068   457776           NaN             NaN                             NaN
# 44465   465278           NaN             NaN                             NaN
# 43966   465876           NaN             NaN                             NaN
# 39823   456635           NaN             NaN                             NaN
# ...        ...           ...             ...                             ...
# 9348    228626       18037.0               N                  No Information
# 70759   217613        9133.0             SSA  Sediment Siliciclastic Arenite
# 72734   212770        5661.0             SSL   Sediment Siliciclastic Lutite
# 1630    211054        4430.0             SSL   Sediment Siliciclastic Lutite
# 8176    226520       15931.0               N                  No Information
#
#       LITHOLOGY_CODE  LITHOLOGY_NAME MAP_SYMBOL  STRUCTURE_NO STRUCTRE_CODE  \
# 21053           SLST       Siltstone        Nnt         50871          SPSH
# 66068            NaN             NaN        NaN         63067          SPSH
# 44465            NaN             NaN        NaN         55473           STS
# 43966            NaN             NaN        NaN         56603           LTI
# 39823            NaN             NaN        NaN         61601           STS
# ...              ...             ...        ...           ...           ...
# 9348            XXXX  No Information        NaN         14887          SPSH
# 70759           SDST       Sandstone        Elm          5065          SPSH
# 72734           SLST       Siltstone        N-r          3083          STSC
# 1630            SLST       Siltstone        Nds          2423          SPSH
# 8176            XXXX  No Information        NaN         11845          SPSH
#
#                                   STRUCTURE_NAME STRUCTURE_CONF  \
# 21053  Originally horizontal sedimentary bedding            NaN
# 66068  Originally horizontal sedimentary bedding            NaN
# 44465                         Tectonic foliation            NaN
# 43966                     Intersection lineation            NaN
# 39823                         Tectonic foliation            NaN
# ...                                          ...            ...
# 9348   Originally horizontal sedimentary bedding            NaN
# 70759  Originally horizontal sedimentary bedding            NaN
# 72734                             Slaty cleavage            NaN
# 1630   Originally horizontal sedimentary bedding            NaN
# 8176   Originally horizontal sedimentary bedding            NaN
#
#        LOCAL_GENERATION             OROGENY  REGIONAL_GENERATION  AZIMUTH  \
# 21053               0.0                 NaN                  NaN    256.0
# 66068               0.0                 NaN                  NaN    163.0
# 44465               1.0  Delamerian Orogeny                  NaN    107.0
# 43966               1.0  Delamerian Orogeny                  NaN    348.0
# 39823               1.0  Delamerian Orogeny                  NaN    278.0
# ...                 ...                 ...                  ...      ...
# 9348                0.0  Delamerian Orogeny                  NaN    183.0
# 70759               NaN                 NaN                  NaN      7.0
# 72734               1.0                 NaN                  NaN    350.0
# 1630                0.0  Delamerian Orogeny                  NaN    266.0
# 8176                0.0  Delamerian Orogeny                  NaN     99.0
#
#        AZIMUTH_ACCURACY AZIMUTH_MEASUREMENT_TYPE  INCLINATION  \
# 21053               2.0                        M         75.0
# 66068               2.0                        M         55.0
# 44465               2.0                        M         80.0
# 43966               2.0                        M         60.0
# 39823               2.0                        M         58.0
# ...                 ...                      ...          ...
# 9348                2.0                        M         90.0
# 70759               2.0                        M         50.0
# 72734               2.0                        M         70.0
# 1630                2.0                        M         66.0
# 8176                2.0                        M         69.0
#
#        INCLINATION_ACCURACY YOUNGING OBSERVATION_DATE  EASTING_GDA2020  \
# 21053                   2.0      NaN       21/05/1995        295400.19
# 66068                   2.0      NaN       13/03/2001        271384.40
# 44465                   2.0      NaN              NaN        230131.03
# 43966                   2.0      NaN              NaN        260043.22
# 39823                   2.0      NaN       11/08/1999        283842.22
# ...                     ...      ...              ...              ...
# 9348                    2.0      NaN       19/06/1990        353757.97
# 70759                   2.0      NaN       22/03/1995        639315.64
# 72734                   2.0      NaN       01/08/1988        360549.55
# 1630                    2.0      NaN       23/11/1994        327194.01
# 8176                    2.0      NaN       22/10/1991        331756.57
#
#        NORTHING_GDA2020  ZONE_GDA2020  LONGITUDE_GDA2020  LATITUDE_GDA2020  \
# 21053        6282340.61            54         138.795494        -33.579034
# 66068        6296661.28            54         138.540584        -33.445109
# 44465        6342780.04            54         138.110947        -33.020056
# 43966        6332615.37            54         138.428207        -33.118653
# 39823        6298995.68            54         138.675066        -33.426656
# ...                 ...           ...                ...               ...
# 9348         6347922.76            54         139.434632        -32.997314
# 70759        6026725.34            53         136.543634        -35.893843
# 72734        7015188.02            53         133.594817        -26.978339
# 1630         6287373.44            54         139.138865        -33.539293
# 8176         6332649.78            54         139.196417        -33.131838
#
#        LONGITUDE_GDA94  LATITUDE_GDA94
# 21053       138.795484      -33.579020
# 66068       138.540574      -33.445094
# 44465       138.110937      -33.020042
# 43966       138.428197      -33.118639
# 39823       138.675056      -33.426641
# ...                ...             ...
# 9348        139.434622      -32.997299
# 70759       136.543625      -35.893829
# 72734       133.594808      -26.978325
# 1630        139.138855      -33.539278
# 8176        139.196407      -33.131823
#
# [500 rows x 28 columns]

# %%
sarig_fieldobs_struct_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72873 entries, 0 to 72872
# Data columns (total 28 columns):
# SITE_NO                     72873 non-null int64
# LITHOLOGY_NO                40987 non-null float64
# ROCK_GROUP_CODE             40987 non-null object
# ROCK_GROUP                  40987 non-null object
# LITHOLOGY_CODE              40987 non-null object
# LITHOLOGY_NAME              40987 non-null object
# MAP_SYMBOL                  30177 non-null object
# STRUCTURE_NO                72873 non-null int64
# STRUCTRE_CODE               72873 non-null object
# STRUCTURE_NAME              72873 non-null object
# STRUCTURE_CONF              2138 non-null object
# LOCAL_GENERATION            38008 non-null float64
# OROGENY                     36124 non-null object
# REGIONAL_GENERATION         16032 non-null float64
# AZIMUTH                     72832 non-null float64
# AZIMUTH_ACCURACY            72872 non-null float64
# AZIMUTH_MEASUREMENT_TYPE    72872 non-null object
# INCLINATION                 72842 non-null float64
# INCLINATION_ACCURACY        72867 non-null float64
# YOUNGING                    1700 non-null object
# OBSERVATION_DATE            40427 non-null object
# EASTING_GDA2020             72873 non-null float64
# NORTHING_GDA2020            72873 non-null float64
# ZONE_GDA2020                72873 non-null int64
# LONGITUDE_GDA2020           72873 non-null float64
# LATITUDE_GDA2020            72873 non-null float64
# LONGITUDE_GDA94             72873 non-null float64
# LATITUDE_GDA94              72873 non-null float64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 15.6+ MB

# %%
interest_fieldobs_struct_exp = sarig_fieldobs_struct_exp[['SITE_NO', 'LITHOLOGY_NO', 'STRUCTURE_NO', 'STRUCTRE_CODE', 
    'LOCAL_GENERATION', 'OROGENY', 'REGIONAL_GENERATION', 'AZIMUTH', 
    'AZIMUTH_ACCURACY', 'AZIMUTH_MEASUREMENT_TYPE', 'INCLINATION', 
    'INCLINATION_ACCURACY']]

# %%
merged_fieldobs_exp = interested_fieldobs_exp.merge(
    interested_fieldobs_litho_exp, how='inner', on='SITE_NO').merge(
    interest_fieldobs_struct_exp, how='inner', on=['SITE_NO','LITHOLOGY_NO'])

# %%
merged_fieldobs_exp.sample(10)
# Out:
#        SITE_NO        FIELD_ID LANDFORM_CODE        MAP_250000  \
# 39193   218542  6326-iv/r3/172           NaN  SI5316 KINGSCOTE
# 21879   225454   0241401191135           NaN      SI5405 BURRA
# 22625   222279   0029225511006           NaN  SG5215 BIRKSGATE
# 30771  1107183             NaN           NaN  SH5414 CURNAMONA
# 2030    219035            DB87           NaN     SI5413 BARKER
# 10754   278160   0266100971013           NaN    SI5311 LINCOLN
# 11542   296027   0266200161002           NaN    SI5311 LINCOLN
# 4000    224228   0241500651038           NaN      SI5405 BURRA
# 11037   285216   2413B01201451           NaN      SI5405 BURRA
# 8921    265886   0355601201208           NaN      SI5405 BURRA
#
#             MAP_100000  MAP_50000  EASTING_GDA2020  NORTHING_GDA2020  \
# 39193     6326 Vivonne          4        693251.46        6054059.63
# 21879     6731 Caroona          3        323484.99        6292376.66
# 22625  4943 Unmoorinna          3        604209.11        6968716.16
# 30771    6934 Kalabity          3        414096.68        6462596.49
# 2030   6527 Yankalilla          2        257680.70        6078830.32
# 10754     6028 Lincoln          1        570011.72        6160856.78
# 11542     6128 Spilsby          4        591830.74        6180680.69
# 4000      6731 Caroona          3        315442.69        6308410.17
# 11037       6630 Clare          3        274526.60        6249177.60
# 8921    6730 Florieton          3        314855.88        6261608.43
#
#        ZONE_GDA2020  LONGITUDE_GDA2020  LATITUDE_GDA2020  LONGITUDE_GDA94  \
# 39193            53         137.134336        -35.638396       137.134326
# 21879            54         139.099924        -33.493583       139.099914
# 22625            52         130.054064        -27.400925       130.054055
# 30771            54         140.090859        -31.969389       140.090849
# 2030             54         138.331615        -35.404474       138.331605
# 10754            53         135.764376        -34.691905       135.764366
# 11542            53         136.000418        -34.511433       136.000408
# 4000             54         139.016688        -33.347695       139.016678
# 11037            54         138.562317        -33.873663       138.562307
# 8921             54         139.000685        -33.769469       139.000675
#
#        LATITUDE_GDA94  HORIZ_ACCRCY_M  ELEVATION_M  VERT_ACCRCY_M  \
# 39193      -35.638382             NaN          NaN            NaN
# 21879      -33.493569             NaN          NaN            NaN
# 22625      -27.400911             NaN          NaN            NaN
# 30771      -31.969375             4.0          NaN            NaN
# 2030       -35.404460             NaN          NaN            NaN
# 10754      -34.691891             NaN          NaN            NaN
# 11542      -34.511419             NaN          NaN            NaN
# 4000       -33.347680             NaN          NaN            NaN
# 11037      -33.873648             NaN          NaN            NaN
# 8921       -33.769454             NaN          NaN            NaN
#
#       SURVEY_METHOD_CODE  LITHOLOGY_NO MAP_SYMBOL    GIS_CODE  STRAT_UNIT_NO  \
# 39193                NaN         10204        Eat      E-oa-t           4667
# 21879                NaN         14865        NaN         NaN            NaN
# 22625              PHOTO         12895        Emt      E-om-t           4230
# 30771              GPSAP         58752        Lwh       L-wrh           6407
# 2030                 NaN         10736        Enh      E-on-h           3635
# 10754              PHOTO         33027        Lhw      L--h-w           4280
# 11542              PHOTO         32445        Ldw      L--d-w           4836
# 4000                 NaN         13639        Nyw      N-huyw           4684
# 11037              PHOTO         36332       Novs     N-wbovs           6226
# 8921               PHOTO         41577       Ndw2  N-wbdw--02           5991
#
#       ROCK_GROUP_CODE LITHO_CODE LITHO_CONFIDENCE LITHO_MODIFIER  \
# 39193             SSA       SDST              NaN            NaN
# 21879               N       XXXX              NaN            NaN
# 22625             SSA       SDST              NaN    FELDSPATHIC
# 30771              MS       PELT              NaN            NaN
# 2030                N       XXXX              NaN            NaN
# 10754              MS       QTZT              NaN            NaN
# 11542              MG       GNSS              NaN            NaN
# 4000              SSL       SLST              NaN            NaN
# 11037              MG       SCHT              NaN            NaN
# 8921              SCC       DLOM              NaN         Silty.
#
#        STRUCTURE_NO STRUCTRE_CODE  LOCAL_GENERATION             OROGENY  \
# 39193          5898           STF               NaN                 NaN
# 21879         10479          STSC               1.0  Delamerian Orogeny
# 22625          7959           STS               NaN                 NaN
# 30771         65273          SPSH               NaN     Olarian Orogeny
# 2030           6290          SPSD               NaN                 NaN
# 10754         36198           STS               NaN      Kimban Orogeny
# 11542         35559             L               NaN      Kimban Orogeny
# 4000           8532          STSC               1.0  Delamerian Orogeny
# 11037         39276          STSN               3.0  Delamerian Orogeny
# 8921          43787          SPSH               0.0  Delamerian Orogeny
#
#        REGIONAL_GENERATION  AZIMUTH  AZIMUTH_ACCURACY  \
# 39193                  NaN     20.0               2.0
# 21879                  NaN     94.0               2.0
# 22625                  NaN    337.0               5.0
# 30771                  NaN    157.0               2.0
# 2030                   NaN    233.0               2.0
# 10754                  NaN    134.0               2.0
# 11542                  3.0     70.0               2.0
# 4000                   NaN    298.0               2.0
# 11037                  NaN    240.0               2.0
# 8921                   NaN    237.0               2.0
#
#       AZIMUTH_MEASUREMENT_TYPE  INCLINATION  INCLINATION_ACCURACY
# 39193                        M         61.0                   2.0
# 21879                        M         83.0                   2.0
# 22625                        M         25.0                   5.0
# 30771                        M         35.0                   2.0
# 2030                         M         24.0                   2.0
# 10754                        M         60.0                   2.0
# 11542                        M         70.0                   2.0
# 4000                         M         67.0                   2.0
# 11037                        M         87.0                   2.0
# 8921                         M         86.0                   2.0

# %%
merged_fieldobs_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40973 entries, 0 to 40972
# Data columns (total 35 columns):
# SITE_NO                     40973 non-null int64
# FIELD_ID                    39408 non-null object
# LANDFORM_CODE               1455 non-null object
# MAP_250000                  40973 non-null object
# MAP_100000                  40973 non-null object
# MAP_50000                   40973 non-null int64
# EASTING_GDA2020             40973 non-null float64
# NORTHING_GDA2020            40973 non-null float64
# ZONE_GDA2020                40973 non-null int64
# LONGITUDE_GDA2020           40973 non-null float64
# LATITUDE_GDA2020            40973 non-null float64
# LONGITUDE_GDA94             40973 non-null float64
# LATITUDE_GDA94              40973 non-null float64
# HORIZ_ACCRCY_M              5863 non-null float64
# ELEVATION_M                 4101 non-null float64
# VERT_ACCRCY_M               3944 non-null float64
# SURVEY_METHOD_CODE          28289 non-null object
# LITHOLOGY_NO                40973 non-null int64
# MAP_SYMBOL                  30164 non-null object
# GIS_CODE                    30164 non-null object
# STRAT_UNIT_NO               30167 non-null Int64
# ROCK_GROUP_CODE             40973 non-null object
# LITHO_CODE                  40973 non-null object
# LITHO_CONFIDENCE            252 non-null object
# LITHO_MODIFIER              15211 non-null object
# STRUCTURE_NO                40973 non-null int64
# STRUCTRE_CODE               40973 non-null object
# LOCAL_GENERATION            28450 non-null float64
# OROGENY                     28622 non-null object
# REGIONAL_GENERATION         1292 non-null float64
# AZIMUTH                     40937 non-null float64
# AZIMUTH_ACCURACY            40972 non-null float64
# AZIMUTH_MEASUREMENT_TYPE    40972 non-null object
# INCLINATION                 40947 non-null float64
# INCLINATION_ACCURACY        40970 non-null float64
# dtypes: Int64(1), float64(15), int64(5), object(14)
# memory usage: 11.3+ MB

# %%
sorted(merged_fieldobs_exp.columns)
# Out:
# ['AZIMUTH',
#  'AZIMUTH_ACCURACY',
#  'AZIMUTH_MEASUREMENT_TYPE',
#  'EASTING_GDA2020',
#  'ELEVATION_M',
#  'FIELD_ID',
#  'GIS_CODE',
#  'HORIZ_ACCRCY_M',
#  'INCLINATION',
#  'INCLINATION_ACCURACY',
#  'LANDFORM_CODE',
#  'LATITUDE_GDA2020',
#  'LATITUDE_GDA94',
#  'LITHOLOGY_NO',
#  'LITHO_CODE',
#  'LITHO_CONFIDENCE',
#  'LITHO_MODIFIER',
#  'LOCAL_GENERATION',
#  'LONGITUDE_GDA2020',
#  'LONGITUDE_GDA94',
#  'MAP_100000',
#  'MAP_250000',
#  'MAP_50000',
#  'MAP_SYMBOL',
#  'NORTHING_GDA2020',
#  'OROGENY',
#  'REGIONAL_GENERATION',
#  'ROCK_GROUP_CODE',
#  'SITE_NO',
#  'STRAT_UNIT_NO',
#  'STRUCTRE_CODE',
#  'STRUCTURE_NO',
#  'SURVEY_METHOD_CODE',
#  'VERT_ACCRCY_M',
#  'ZONE_GDA2020']

# %%
merged_fieldobs_exp.to_csv('merged_fieldobs_exp.csv', sep=',', header='infer')
