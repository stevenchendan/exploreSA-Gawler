# %% [markdown]
# ## Surface Observation Data Processing

# %%
# import required packages
import pandas as pd
import os
import pickle
import sys
pd.options.display.width=None
pd.options.display.max_columns=None


if sys.version_info >= (3, 6):
    from zipfile import ZipFile as zipfile
else:
    import zipfile36 as zipfile
    
url = "https://unearthed-exploresa.s3-ap-southeast-2.amazonaws.com/Unearthed_5_SARIG_Data_Package.zip" 
# enter the directory to save data
data_loc = './data'
file_name = 'Unearthed_5_SARIG_Data_Package.zip'

if os.path.isfile(os.path.join(data_loc, file_name)):
    print ("File exist")
    pass
else:
    # open and save the zip file onto computer
    url = urlopen(URL)
    output = open('./data/Unearthed_5_SARIG_Data_Package.zip', 'wb')    # note the flag:  "wb"        
    output.write(url.read())
    output.close()
    
files_in_dataset = []
file_name = 'Unearthed_5_SARIG_Data_Package.zip'
for file in zipfile(os.path.join(data_loc, file_name),'r').filelist:
    files_in_dataset.append(file.filename)
    
files_in_dataset
# Out:
# File exist
# ['SARIG_Data_Package/sarig_dh_core_exp.csv',
#  'SARIG_Data_Package/sarig_dh_details_exp.csv',
#  'SARIG_Data_Package/sarig_dh_litho_exp.csv',
#  'SARIG_Data_Package/sarig_dh_petrophys_exp.csv',
#  'SARIG_Data_Package/sarig_dh_reference_exp.csv',
#  'SARIG_Data_Package/sarig_dh_strat_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_litho_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_note_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_struct_exp.csv',
#  'SARIG_Data_Package/sarig_md_commodity_exp.csv',
#  'SARIG_Data_Package/sarig_md_details_exp.csv',
#  'SARIG_Data_Package/sarig_md_mineralogy_exp.csv',
#  'SARIG_Data_Package/sarig_md_reference_exp.csv',
#  'SARIG_Data_Package/sarig_md_zone_hr_lith_exp.csv',
#  'SARIG_Data_Package/sarig_md_zone_lith_exp.csv',
#  'SARIG_Data_Package/sarig_rs_biostr_analys_exp.csv',
#  'SARIG_Data_Package/sarig_rs_biostr_results_exp.csv',
#  'SARIG_Data_Package/sarig_rs_chem_exp.csv',
#  'SARIG_Data_Package/sarig_rs_chem_isotope_exp.csv',
#  'SARIG_Data_Package/sarig_rs_details_exp.csv',
#  'SARIG_Data_Package/sarig_rs_geochron_ages_exp.csv',
#  'SARIG_Data_Package/sarig_rs_geochron_reslt_exp.csv',
#  'SARIG_Data_Package/sarig_rs_petrology_exp.csv',
#  'SARIG_Data_Package/sarig_rs_reference_exp.csv',
#  'SARIG_Data_Package/vocabulary_codes_descriptions/',
#  'SARIG_Data_Package/vocabulary_codes_descriptions/chem_method_code_desc.csv',
#  'SARIG_Data_Package/vocabulary_codes_descriptions/lithology_code_desc.csv',
#  'SARIG_Data_Package/vocabulary_codes_descriptions/petro_type_code_desc.csv',
#  'SARIG_Data_Package/vocabulary_codes_descriptions/strat_unit_code_desc.csv',
#  'SARIG_Data_Package/vocabulary_codes_descriptions/Stratigraphic Unit Letter Code System - Explanation of the GIS Search Code and Map Symbol.pdf',
#  'SARIG_Data_Package/vocabulary_codes_descriptions/unit_code_desc.csv']

# %% [markdown]
# For this part of data cleaning, we will only use the following files:
#  - 'SARIG_Data_Package/sarig_fieldobs_exp.csv',
#  - 'SARIG_Data_Package/sarig_fieldobs_litho_exp.csv',
#  - 'SARIG_Data_Package/sarig_fieldobs_note_exp.csv',
#  - 'SARIG_Data_Package/sarig_fieldobs_struct_exp.csv'

# %% [markdown]
# ### Load Field Observation Data

# %%
# load the field observation summary data
sarig_fieldobs_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_fieldobs_exp.csv','r'), 
    sep=',', encoding='latin1')
sarig_fieldobs_exp.sample(5)
# Out:
# C:\Program Files\Python36\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        SITE_NO       FIELD_ID        OBSERVER OBSERVATION_DATE FIELD_NOTE  \
# 43076  1848898       SG-00053  MCAVANEY, S.O.       01/02/2013          N
# 27905   226993  0241201271072             NaN              NaN          N
# 86714   228224  0241300121005             NaN              NaN          N
# 3395    208770  0073601261021     MAJOR, R.B.              NaN          Y
# 75138  1807636        TRUS036     RUSAK, T.M.       04/09/2011          Y
#
#       LITHOLOGY STRUCTURE ROCK_SAMPLE IMAGE LANDFORM_CODE LANDFORM_DESC  \
# 43076         Y         N           N     Y           NaN           NaN
# 27905         Y         Y           N     N           NaN           NaN
# 86714         Y         Y           N     N           NaN           NaN
# 3395          N         N           N     N           NaN           NaN
# 75138         Y         N           N     N           NaN           NaN
#
#                 MAP_250000     MAP_100000  MAP_50000  EASTING_GDA2020  \
# 43076  SI5304 PORT AUGUSTA   6432 Cultana          1        779614.26
# 27905         SI5405 BURRA   6731 Caroona          4        334453.63
# 86714         SI5405 BURRA   6731 Caroona          1        345629.98
# 3395        SG5313 EVERARD  5443 Etitinna          3        273904.28
# 75138       SG5310 ABMINGA    5645 Tieyon          4        372949.68
#
#        NORTHING_GDA2020  ZONE_GDA2020  LONGITUDE_GDA2020  LATITUDE_GDA2020  \
# 43076        6378462.89            53         137.982473        -32.696157
# 27905        6341646.33            54         139.226947        -33.051141
# 86714        6325552.91            54         139.343882        -33.197890
# 3395         6975794.69            53         132.714959        -27.322313
# 75138        7119921.88            53         133.730180        -26.034099
#
#        LONGITUDE_GDA94  LATITUDE_GDA94  HORIZ_ACCRCY_M  ELEVATION_M  \
# 43076       137.982463      -32.696143             5.0        160.7
# 27905       139.226937      -33.051127             NaN          NaN
# 86714       139.343872      -33.197876             NaN          NaN
# 3395        132.714950      -27.322299             NaN          NaN
# 75138       133.730171      -26.034085             5.0        476.9
#
#        VERT_ACCRCY_M SURVEY_METHOD_CODE                SURVEY_METHOD COMMENTS
# 43076           10.0              GPSSN  GPS Standalone Navigational      NaN
# 27905            NaN                NaN                          NaN      NaN
# 86714            NaN                NaN                          NaN      NaN
# 3395             NaN                NaN                          NaN      NaN
# 75138            NaN              GPSSN  GPS Standalone Navigational      NaN

# %%
interested_fieldobs_exp = sarig_fieldobs_exp[['SITE_NO', 'FIELD_ID', 
       'LANDFORM_CODE', 'MAP_250000', 'MAP_100000', 'MAP_50000',
       'EASTING_GDA2020', 'NORTHING_GDA2020', 'ZONE_GDA2020',
       'LONGITUDE_GDA2020', 'LATITUDE_GDA2020', 'LONGITUDE_GDA94',
       'LATITUDE_GDA94', 'HORIZ_ACCRCY_M', 'ELEVATION_M', 'VERT_ACCRCY_M',
       'SURVEY_METHOD_CODE']]
interested_fieldobs_exp.sample(5)
# Out:
#        SITE_NO       FIELD_ID LANDFORM_CODE      MAP_250000      MAP_100000  \
# 73978   460033  0355300541011           NaN    SI5405 BURRA  6631 Jamestown
# 31192   267993  0355601651196           NaN    SI5405 BURRA      6630 Clare
# 70319  1970747      ALMP00050          FACF  SG5309 ALBERGA    5545 Alcurra
# 73387   266358  0355601141135           NaN    SI5405 BURRA      6630 Clare
# 75698  2008372     BN_RP00275          MLPT   SI5303 YARDEA  6132 Buckleboo
#
#        MAP_50000  EASTING_GDA2020  NORTHING_GDA2020  ZONE_GDA2020  \
# 73978          4        277928.66        6341358.85            54
# 31192          4        288597.32        6269379.75            54
# 70319          1        342922.49        7100060.52            53
# 73387          1        307433.00        6272978.16            54
# 75698          1        629446.71        6386861.75            53
#
#        LONGITUDE_GDA2020  LATITUDE_GDA2020  LONGITUDE_GDA94  LATITUDE_GDA94  \
# 73978         138.621872        -33.043661       138.621862      -33.043647
# 31192         138.719166        -33.694515       138.719156      -33.694500
# 70319         133.427753        -26.210425       133.427744      -26.210411
# 73387         138.923043        -33.665664       138.923033      -33.665650
# 75698         136.380198        -32.648286       136.380188      -32.648272
#
#        HORIZ_ACCRCY_M  ELEVATION_M  VERT_ACCRCY_M SURVEY_METHOD_CODE
# 73978             NaN          NaN            NaN              PHOTO
# 31192             NaN          NaN            NaN              PHOTO
# 70319            10.0        449.1           20.0              GPSSN
# 73387             NaN          NaN            NaN              PHOTO
# 75698            10.0        294.0           20.0              GPSSN

# %%
sarig_fieldobs_exp.columns
# Out:
# Index(['SITE_NO', 'FIELD_ID', 'OBSERVER', 'OBSERVATION_DATE', 'FIELD_NOTE',
#        'LITHOLOGY', 'STRUCTURE', 'ROCK_SAMPLE', 'IMAGE', 'LANDFORM_CODE',
#        'LANDFORM_DESC', 'MAP_250000', 'MAP_100000', 'MAP_50000',
#        'EASTING_GDA2020', 'NORTHING_GDA2020', 'ZONE_GDA2020',
#        'LONGITUDE_GDA2020', 'LATITUDE_GDA2020', 'LONGITUDE_GDA94',
#        'LATITUDE_GDA94', 'HORIZ_ACCRCY_M', 'ELEVATION_M', 'VERT_ACCRCY_M',
#        'SURVEY_METHOD_CODE', 'SURVEY_METHOD', 'COMMENTS'],
#       dtype='object')

# %%
sarig_fieldobs_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88221 entries, 0 to 88220
# Data columns (total 27 columns):
# SITE_NO               88221 non-null int64
# FIELD_ID              63727 non-null object
# OBSERVER              70938 non-null object
# OBSERVATION_DATE      19638 non-null object
# FIELD_NOTE            88221 non-null object
# LITHOLOGY             88221 non-null object
# STRUCTURE             88221 non-null object
# ROCK_SAMPLE           88221 non-null object
# IMAGE                 88221 non-null object
# LANDFORM_CODE         6208 non-null object
# LANDFORM_DESC         6208 non-null object
# MAP_250000            88221 non-null object
# MAP_100000            88221 non-null object
# MAP_50000             88221 non-null int64
# EASTING_GDA2020       88221 non-null float64
# NORTHING_GDA2020      88221 non-null float64
# ZONE_GDA2020          88221 non-null int64
# LONGITUDE_GDA2020     88221 non-null float64
# LATITUDE_GDA2020      88221 non-null float64
# LONGITUDE_GDA94       88221 non-null float64
# LATITUDE_GDA94        88221 non-null float64
# HORIZ_ACCRCY_M        17449 non-null float64
# ELEVATION_M           12067 non-null float64
# VERT_ACCRCY_M         10627 non-null float64
# SURVEY_METHOD_CODE    62798 non-null object
# SURVEY_METHOD         62798 non-null object
# COMMENTS              1407 non-null object
# dtypes: float64(9), int64(3), object(15)
# memory usage: 18.2+ MB

# %% [markdown]
# This data table includes the summary of the contents of the field observation dataset.

# %% [markdown]
# ### Load the Field Observation Lithology Data

# %%
sarig_fieldobs_litho_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_fieldobs_litho_exp.csv','r'), 
    sep=',', encoding='latin1')
sarig_fieldobs_litho_exp['STRAT_UNIT_NO'] = sarig_fieldobs_litho_exp['STRAT_UNIT_NO'].astype('Int64')
sarig_fieldobs_litho_exp['OBSERVATION_DATE'] = pd.to_datetime(sarig_fieldobs_litho_exp['OBSERVATION_DATE'])
sarig_fieldobs_litho_exp.sample(5)
# Out:
#        SITE_NO  LITHOLOGY_NO MAP_SYMBOL GIS_CODE  STRAT_UNIT_NO STRAT_CONF  \
# 10844   227828         17239        NaN      NaN            NaN        NaN
# 44616  2012025         75665       Maym  M-a--ym           6348        NaN
# 41578  1131186         59632       Lweo   L-wceo           5551        NaN
# 60986  1993881         72246        NaN      NaN            NaN        NaN
# 57842   237091         22883        Nds   N-wbds           4127        NaN
#
#                     STRAT_NAME  \
# 10844                      NaN
# 44616   Moonaree Dacite Member
# 41578  Tommie Wattie Formation
# 60986                      NaN
# 57842    Saddleworth Formation
#
#                                        STRAT_DESCRIPTION ROCK_GROUP_CODE  \
# 10844                                                NaN               N
# 44616  Dacite, massive, red, commonly columnar jointe...             IFE
# 41578  Psammite, in lower part; grades up to pelite, ...              MS
# 60986                                                NaN               G
# 57842   Mudstone; siltstone; shale, partly carbonaceous.             SSL
#
#                           ROCK_GROUP LITHO_CODE LITHO_CONFIDENCE  \
# 10844                 No Information       XXXX              NaN
# 44616       Igneous Felsic Extrusive       DACT              NaN
# 41578                   Metasediment       QTZT              NaN
# 60986          General/Miscellaneous       QZRU              NaN
# 57842  Sediment Siliciclastic Lutite       SLST              NaN
#
#                      LITHOLOGY_NAME  \
# 10844                No Information
# 44616                        Dacite
# 41578                     Quartzite
# 60986  Quartz Rock (Undiff. Origin)
# 57842                     Siltstone
#
#                                       LITHO_MODIFIER  \
# 10844                                            NaN
# 44616  porphyritic, Feldspar, moderate reddish brown
# 41578                                            NaN
# 60986                                         quartz
# 57842                                       Cleaved.
#
#                                           LITHO_COMMENTS OBSERVATION_DATE  \
# 10844                                                NaN              NaT
# 44616                                                NaN       2015-10-28
# 41578                                                NaN              NaT
# 60986  Purple-grey siliceous rock brecciated and ceme...       2014-03-11
# 57842  Blue-grey, purple weathering; occurs to E of l...       1994-01-20
#
#        EASTING_GDA2020  NORTHING_GDA2020  ZONE_GDA2020  LONGITUDE_GDA2020  \
# 10844        340872.74        6304714.96            54         139.289201
# 44616        538674.81        6416416.12            53         135.411193
# 41578        414441.71        6460596.55            54         140.094333
# 60986        702711.27        6396141.77            53         137.158965
# 57842        323854.24        6259684.44            54         139.097424
#
#        LATITUDE_GDA2020  LONGITUDE_GDA94  LATITUDE_GDA94
# 10844        -33.385073       139.289191      -33.385059
# 44616        -32.388592       135.411183      -32.388578
# 41578        -31.987455       140.094323      -31.987441
# 60986        -32.553616       137.158955      -32.553602
# 57842        -33.788348       139.097414      -33.788333

# %%
sarig_fieldobs_litho_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66212 entries, 0 to 66211
# Data columns (total 23 columns):
# SITE_NO              66212 non-null int64
# LITHOLOGY_NO         66212 non-null int64
# MAP_SYMBOL           46529 non-null object
# GIS_CODE             46529 non-null object
# STRAT_UNIT_NO        46587 non-null Int64
# STRAT_CONF           3710 non-null object
# STRAT_NAME           46587 non-null object
# STRAT_DESCRIPTION    46586 non-null object
# ROCK_GROUP_CODE      66212 non-null object
# ROCK_GROUP           66212 non-null object
# LITHO_CODE           66212 non-null object
# LITHO_CONFIDENCE     1114 non-null object
# LITHOLOGY_NAME       66212 non-null object
# LITHO_MODIFIER       30038 non-null object
# LITHO_COMMENTS       24365 non-null object
# OBSERVATION_DATE     41456 non-null datetime64[ns]
# EASTING_GDA2020      66212 non-null float64
# NORTHING_GDA2020     66212 non-null float64
# ZONE_GDA2020         66212 non-null int64
# LONGITUDE_GDA2020    66212 non-null float64
# LATITUDE_GDA2020     66212 non-null float64
# LONGITUDE_GDA94      66212 non-null float64
# LATITUDE_GDA94       66212 non-null float64
# dtypes: Int64(1), datetime64[ns](1), float64(6), int64(3), object(12)
# memory usage: 11.7+ MB

# %%
interested_fieldobs_litho_exp = sarig_fieldobs_litho_exp[
    ['SITE_NO', 'LITHOLOGY_NO', 'MAP_SYMBOL', 'GIS_CODE', 'STRAT_UNIT_NO', 
     'ROCK_GROUP_CODE', 'LITHO_CODE', 'LITHO_CONFIDENCE', 'LITHO_MODIFIER']]
interested_fieldobs_litho_exp.sample(5)
# Out:
#        SITE_NO  LITHOLOGY_NO MAP_SYMBOL  GIS_CODE  STRAT_UNIT_NO  \
# 31290   303049         34269      Qp\ca  I-----ca           4429
# 32604   309190         36621        Nli    N-wbli           3825
# 62782   271319         29673       Novs   N-wbovs           6226
# 33934   311917         38534        Nli    N-wbli           3825
# 52041  1993807         72164        NaN       NaN            NaN
#
#       ROCK_GROUP_CODE LITHO_CODE LITHO_CONFIDENCE  \
# 31290            RPDC       CALC              NaN
# 32604             SSL       SLST              NaN
# 62782             SSL       SLST              NaN
# 33934             SSL       SLST              NaN
# 52041               G       QZRU              NaN
#
#                                           LITHO_MODIFIER
# 31290                                                NaN
# 32604                                                NaN
# 62782  Fine sandy, micromicaceous, with faint laminat...
# 33934                                                NaN
# 52041                                             quartz

# %% [markdown]
# ### Load Field Observation Notes

# %%
sarig_fieldobs_note_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_fieldobs_note_exp.csv','r'), 
    sep=',', encoding='latin1')
sarig_fieldobs_litho_exp['OBSERVATION_DATE'] = pd.to_datetime(sarig_fieldobs_litho_exp['OBSERVATION_DATE'])
sarig_fieldobs_note_exp.sample(5)
# Out:
#        SITE_NO  FIELD_NOTE_NO  \
# 4169    154001           5117
# 12580   474732          16678
# 23401  1971863          32690
# 7204    234601           8633
# 18487  1841610          29182
#
#                                              FIELD_NOTES OBSERVATION_DATE  \
# 4169   Interbedded shales and thin conglomerate lense...              NaN
# 12580                     Mylonitisation as ?D2 feature.       20/10/2000
# 23401           Dolerite geochem sample. Photo: 8016-19.       27/06/2013
# 7204                                        NOT RECORDED              NaN
# 18487  This site lies within gradational contact betw...       13/10/2012
#
#        EASTING_GDA2020  NORTHING_GDA2020  ZONE_GDA2020  LONGITUDE_GDA2020  \
# 4169         726535.05        6059182.38            53         137.500204
# 12580        416713.65        6451807.47            54         140.117620
# 23401        308885.56        7063021.82            53         133.081690
# 7204         694635.07        7082580.83            52         130.950655
# 18487        781094.12        6392921.27            53         137.993896
#
#        LATITUDE_GDA2020  LONGITUDE_GDA94  LATITUDE_GDA94
# 4169         -35.585179       137.500194      -35.585165
# 12580        -32.066909       140.117610      -32.066895
# 23401        -26.540547       133.081681      -26.540533
# 7204         -26.363566       130.950646      -26.363552
# 18487        -32.565532       137.993885      -32.565518

# %% [markdown]
# The FIELD_NOTES are words, which might require text mining, while these FIELD_NOTES does not give too much insight into the ores. So, we ignore this table.

# %% [markdown]
# ### Load Field Observation Geological Structure Data

# %%
sarig_fieldobs_struct_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_fieldobs_struct_exp.csv','r'), 
    sep=',', encoding='latin1')
sarig_fieldobs_struct_exp.sample(5)
# Out:
#        SITE_NO  LITHOLOGY_NO ROCK_GROUP_CODE                      ROCK_GROUP  \
# 68304  2122901       77612.0             IFI        Igneous Felsic Intrusive
# 68064   457744           NaN             NaN                             NaN
# 12090   242157       25557.0              MG             Metamorphic General
# 28400   281563           NaN             NaN                             NaN
# 19851   262370       45525.0             SSA  Sediment Siliciclastic Arenite
#
#       LITHOLOGY_CODE LITHOLOGY_NAME MAP_SYMBOL  STRUCTURE_NO STRUCTRE_CODE  \
# 68304           GRNT        Granite        NaN         80879           STS
# 68064            NaN            NaN        NaN         61903          SPSH
# 12090           PHYL       Phyllite        Nob         18355          SPSH
# 28400            NaN            NaN        NaN         26300          SPSH
# 19851           SDST      Sandstone        Nya         47041          LTES
#
#                                   STRUCTURE_NAME STRUCTURE_CONF  \
# 68304                         Tectonic foliation            NaN
# 68064  Originally horizontal sedimentary bedding            NaN
# 12090  Originally horizontal sedimentary bedding            NaN
# 28400  Originally horizontal sedimentary bedding            NaN
# 19851                         Fault slickensides            NaN
#
#        LOCAL_GENERATION             OROGENY  REGIONAL_GENERATION  AZIMUTH  \
# 68304               NaN                 NaN                  NaN    321.0
# 68064               0.0                 NaN                  NaN    259.0
# 12090               0.0                 NaN                  0.0     70.0
# 28400               NaN                 NaN                  NaN    265.0
# 19851               NaN  Delamerian Orogeny                  NaN     41.0
#
#        AZIMUTH_ACCURACY AZIMUTH_MEASUREMENT_TYPE  INCLINATION  \
# 68304               2.0                        M         85.0
# 68064               2.0                        M         85.0
# 12090              10.0                        M         45.0
# 28400               2.0                        T          3.0
# 19851               2.0                        M         38.0
#
#        INCLINATION_ACCURACY YOUNGING OBSERVATION_DATE  EASTING_GDA2020  \
# 68304                   2.0      NaN       29/09/2018        388041.00
# 68064                   2.0      NaN       15/09/1999        278296.34
# 12090                   5.0      NaN       10/03/1992        264994.97
# 28400                   2.0      NaN              NaN        251697.24
# 19851                   2.0      NaN       10/01/1996        306892.00
#
#        NORTHING_GDA2020  ZONE_GDA2020  LONGITUDE_GDA2020  LATITUDE_GDA2020  \
# 68304        6652298.71            53         133.836217        -30.255779
# 68064        6295601.26            54         138.614623        -33.456114
# 12090        6257617.53            54         138.461604        -33.795535
# 28400        6773932.09            54         138.447716        -29.138892
# 19851        6266181.14            54         138.915732        -33.726830
#
#        LONGITUDE_GDA94  LATITUDE_GDA94
# 68304       133.836208      -30.255765
# 68064       138.614613      -33.456099
# 12090       138.461594      -33.795521
# 28400       138.447706      -29.138878
# 19851       138.915722      -33.726816

# %%
sarig_fieldobs_struct_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72873 entries, 0 to 72872
# Data columns (total 28 columns):
# SITE_NO                     72873 non-null int64
# LITHOLOGY_NO                40987 non-null float64
# ROCK_GROUP_CODE             40987 non-null object
# ROCK_GROUP                  40987 non-null object
# LITHOLOGY_CODE              40987 non-null object
# LITHOLOGY_NAME              40987 non-null object
# MAP_SYMBOL                  30177 non-null object
# STRUCTURE_NO                72873 non-null int64
# STRUCTRE_CODE               72873 non-null object
# STRUCTURE_NAME              72873 non-null object
# STRUCTURE_CONF              2138 non-null object
# LOCAL_GENERATION            38008 non-null float64
# OROGENY                     36124 non-null object
# REGIONAL_GENERATION         16032 non-null float64
# AZIMUTH                     72832 non-null float64
# AZIMUTH_ACCURACY            72872 non-null float64
# AZIMUTH_MEASUREMENT_TYPE    72872 non-null object
# INCLINATION                 72842 non-null float64
# INCLINATION_ACCURACY        72867 non-null float64
# YOUNGING                    1700 non-null object
# OBSERVATION_DATE            40427 non-null object
# EASTING_GDA2020             72873 non-null float64
# NORTHING_GDA2020            72873 non-null float64
# ZONE_GDA2020                72873 non-null int64
# LONGITUDE_GDA2020           72873 non-null float64
# LATITUDE_GDA2020            72873 non-null float64
# LONGITUDE_GDA94             72873 non-null float64
# LATITUDE_GDA94              72873 non-null float64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 15.6+ MB

# %%
interest_fieldobs_struct_exp = sarig_fieldobs_struct_exp[['SITE_NO', 'LITHOLOGY_NO', 'STRUCTURE_NO', 'STRUCTRE_CODE', 
    'LOCAL_GENERATION', 'OROGENY', 'REGIONAL_GENERATION', 'AZIMUTH', 
    'AZIMUTH_ACCURACY', 'AZIMUTH_MEASUREMENT_TYPE', 'INCLINATION', 
    'INCLINATION_ACCURACY']]

# %% [markdown]
# ### Merge Data Tables

# %%
merged_fieldobs_exp = interested_fieldobs_exp.merge(
    interested_fieldobs_litho_exp, how='inner', on='SITE_NO').merge(
    interest_fieldobs_struct_exp, how='inner', on=['SITE_NO','LITHOLOGY_NO'])

# %%
merged_fieldobs_exp.sample(10)
# Out:
#        SITE_NO       FIELD_ID LANDFORM_CODE           MAP_250000  \
# 11856   309800  2413B01281053           NaN         SI5405 BURRA
# 27968   272290  0355601321079           NaN         SI5405 BURRA
# 15772   225046  0241201971112           NaN         SI5405 BURRA
# 28484   263558  0355600531243           NaN         SI5405 BURRA
# 16502   228650  0241201161056           NaN         SI5405 BURRA
# 31363  1834253            W48           NaN  SI5304 PORT AUGUSTA
# 28085   266324  0355601161015           NaN         SI5405 BURRA
# 24650  1116209            NaN           NaN         SI5402 OLARY
# 11544   296027  0266200161002           NaN       SI5311 LINCOLN
# 30017   295968  0267200131019           NaN       SI5311 LINCOLN
#
#            MAP_100000  MAP_50000  EASTING_GDA2020  NORTHING_GDA2020  \
# 11856      6630 Clare          3        282943.49        6247410.76
# 27968      6630 Clare          3        270678.02        6258744.56
# 15772    6731 Caroona          4        320318.27        6326393.66
# 28484  6631 Jamestown          2        296421.12        6291669.87
# 16502    6731 Caroona          1        354168.60        6336504.37
# 31363    6432 Cultana          1        781034.37        6396689.54
# 28085      6630 Clare          1        311362.41        6271939.49
# 24650      6933 Olary          1        452786.66        6450739.52
# 11544    6128 Spilsby          4        591830.74        6180680.69
# 30017    6128 Spilsby          3        592400.45        6138561.38
#
#        ZONE_GDA2020  LONGITUDE_GDA2020  LATITUDE_GDA2020  LONGITUDE_GDA94  \
# 11856            54         138.652811        -33.891351       138.652801
# 27968            54         138.523231        -33.786628       138.523221
# 15772            54         139.072622        -33.186402       139.072612
# 28484            54         138.808611        -33.495145       138.808601
# 16502            54         139.437208        -33.100327       139.437198
# 31363            53         137.992132        -32.531600       137.992122
# 28085            54         138.965180        -33.675731       138.965170
# 24650            54         140.499727        -32.078628       140.499717
# 11544            53         136.000418        -34.511433       136.000408
# 30017            53         136.011234        -34.891150       136.011224
#
#        LATITUDE_GDA94  HORIZ_ACCRCY_M  ELEVATION_M  VERT_ACCRCY_M  \
# 11856      -33.891336             NaN          NaN            NaN
# 27968      -33.786613             NaN          NaN            NaN
# 15772      -33.186387             NaN          NaN            NaN
# 28484      -33.495131             NaN          NaN            NaN
# 16502      -33.100313             NaN          NaN            NaN
# 31363      -32.531586            15.0          NaN            NaN
# 28085      -33.675717             NaN          NaN            NaN
# 24650      -32.078614            10.0          NaN            NaN
# 11544      -34.511419             NaN          NaN            NaN
# 30017      -34.891136             NaN          NaN            NaN
#
#       SURVEY_METHOD_CODE  LITHOLOGY_NO MAP_SYMBOL GIS_CODE  STRAT_UNIT_NO  \
# 11856              PHOTO         36933        Nli   N-wbli           3825
# 27968              PHOTO         36823       Novs  N-wbovs           6226
# 15772                NaN         14457        NaN      NaN            NaN
# 28484              PHOTO         50405        Nep   N-huep           4045
# 16502                NaN         18061        NaN      NaN            NaN
# 31363              GPSSN         64819        Nee   N-huee           3546
# 28085              PHOTO         48647        Nds   N-wbds           4127
# 24650              GPSAP         59393        NaN      NaN            NaN
# 11544              PHOTO         32445        Ldw   L--d-w           4836
# 30017              PHOTO         32640        Ldw   L--d-w           4836
#
#       ROCK_GROUP_CODE LITHO_CODE LITHO_CONFIDENCE  \
# 11856             SSL       SLST              NaN
# 27968              MG       SCHT              NaN
# 15772               N       XXXX              NaN
# 28484             SSL       SLST              NaN
# 16502               N       XXXX              NaN
# 31363             SSA       SDST              NaN
# 28085             SSL       SLST              NaN
# 24650              MG       MIGM              NaN
# 11544              MG       GNSS              NaN
# 30017             IFI       GRNT              NaN
#
#                                           LITHO_MODIFIER  STRUCTURE_NO  \
# 11856                                                NaN         39966
# 27968                                                NaN         39831
# 15772                                                NaN          9821
# 28484  Pale khaki-grey weathered massive siltstone, c...         51869
# 16502                                                NaN         14918
# 31363  Top of next medium and coarse-grained blocky p...         76727
# 28085                         Dark Grey thinly laminated         50024
# 24650                                                NaN         65538
# 11544                                                NaN         35557
# 30017                                                NaN         35787
#
#       STRUCTRE_CODE  LOCAL_GENERATION             OROGENY  \
# 11856          SPSH               0.0  Delamerian Orogeny
# 27968          STSN               3.0  Delamerian Orogeny
# 15772          SPSH               0.0  Delamerian Orogeny
# 28484          STSC               1.0  Delamerian Orogeny
# 16502          SPSH               0.0  Delamerian Orogeny
# 31363          SPSH               NaN                 NaN
# 28085          STSC               1.0  Delamerian Orogeny
# 24650          STSI               3.0     Olarian Orogeny
# 11544           STS               NaN                 NaN
# 30017          STSM               NaN      Kimban Orogeny
#
#        REGIONAL_GENERATION  AZIMUTH  AZIMUTH_ACCURACY  \
# 11856                  NaN    263.0               2.0
# 27968                  NaN    255.0               2.0
# 15772                  NaN    303.0               2.0
# 28484                  NaN    268.0               2.0
# 16502                  NaN    218.0               2.0
# 31363                  NaN     96.0               2.0
# 28085                  NaN    288.0               2.0
# 24650                  3.0    169.0               2.0
# 11544                  NaN     56.0               2.0
# 30017                  3.0    339.0               2.0
#
#       AZIMUTH_MEASUREMENT_TYPE  INCLINATION  INCLINATION_ACCURACY
# 11856                        M         71.0                   2.0
# 27968                        M         60.0                   2.0
# 15772                        M         75.0                   2.0
# 28484                        M         70.0                   2.0
# 16502                        M         33.0                   2.0
# 31363                        M         90.0                   2.0
# 28085                        M         67.0                   2.0
# 24650                        M         90.0                   2.0
# 11544                        M         80.0                   2.0
# 30017                        M         70.0                   2.0

# %%
merged_fieldobs_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40973 entries, 0 to 40972
# Data columns (total 35 columns):
# SITE_NO                     40973 non-null int64
# FIELD_ID                    39408 non-null object
# LANDFORM_CODE               1455 non-null object
# MAP_250000                  40973 non-null object
# MAP_100000                  40973 non-null object
# MAP_50000                   40973 non-null int64
# EASTING_GDA2020             40973 non-null float64
# NORTHING_GDA2020            40973 non-null float64
# ZONE_GDA2020                40973 non-null int64
# LONGITUDE_GDA2020           40973 non-null float64
# LATITUDE_GDA2020            40973 non-null float64
# LONGITUDE_GDA94             40973 non-null float64
# LATITUDE_GDA94              40973 non-null float64
# HORIZ_ACCRCY_M              5863 non-null float64
# ELEVATION_M                 4101 non-null float64
# VERT_ACCRCY_M               3944 non-null float64
# SURVEY_METHOD_CODE          28289 non-null object
# LITHOLOGY_NO                40973 non-null int64
# MAP_SYMBOL                  30164 non-null object
# GIS_CODE                    30164 non-null object
# STRAT_UNIT_NO               30167 non-null Int64
# ROCK_GROUP_CODE             40973 non-null object
# LITHO_CODE                  40973 non-null object
# LITHO_CONFIDENCE            252 non-null object
# LITHO_MODIFIER              15211 non-null object
# STRUCTURE_NO                40973 non-null int64
# STRUCTRE_CODE               40973 non-null object
# LOCAL_GENERATION            28450 non-null float64
# OROGENY                     28622 non-null object
# REGIONAL_GENERATION         1292 non-null float64
# AZIMUTH                     40937 non-null float64
# AZIMUTH_ACCURACY            40972 non-null float64
# AZIMUTH_MEASUREMENT_TYPE    40972 non-null object
# INCLINATION                 40947 non-null float64
# INCLINATION_ACCURACY        40970 non-null float64
# dtypes: Int64(1), float64(15), int64(5), object(14)
# memory usage: 11.3+ MB

# %% [markdown]
# ### Export Merged Dataset

# %%
merged_fieldobs_exp.to_csv('./data/merged_fieldobs_exp.csv', sep=',', header='infer')
