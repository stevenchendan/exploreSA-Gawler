# %%
# import required packages
import pandas as pd
import os
import pickle
import sys

if sys.version_info >= (3, 6):
    from zipfile import ZipFile as zipfile
else:
    import zipfile36 as zipfile

# %%
url = "https://unearthed-exploresa.s3-ap-southeast-2.amazonaws.com/Unearthed_5_SARIG_Data_Package.zip"

# %%
import os.path

# enter the directory to save data
data_loc = 'D:/GitFolder/WorkBench/exploreSA-Gawler/data'
file_name = 'Unearthed_5_SARIG_Data_Package.zip'

if os.path.isfile(os.path.join(data_loc, file_name)):
    print ("File exist")
    pass
else:
    # open and save the zip file onto computer
    url = urlopen(URL)
    output = open('Unearthed_5_SARIG_Data_Package.zip', 'wb')    # note the flag:  "wb"        
    output.write(url.read())
    output.close()
# Out:
# File exist

# %%
files_in_dataset = []
file_name = 'Unearthed_5_SARIG_Data_Package.zip'
for file in zipfile(os.path.join(data_loc, file_name),'r').filelist:
    files_in_dataset.append(file.filename)
    
files_in_dataset
# Out:
# ['SARIG_Data_Package/sarig_dh_core_exp.csv',
#  'SARIG_Data_Package/sarig_dh_details_exp.csv',
#  'SARIG_Data_Package/sarig_dh_litho_exp.csv',
#  'SARIG_Data_Package/sarig_dh_petrophys_exp.csv',
#  'SARIG_Data_Package/sarig_dh_reference_exp.csv',
#  'SARIG_Data_Package/sarig_dh_strat_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_litho_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_note_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_struct_exp.csv',
#  'SARIG_Data_Package/sarig_md_commodity_exp.csv',
#  'SARIG_Data_Package/sarig_md_details_exp.csv',
#  'SARIG_Data_Package/sarig_md_mineralogy_exp.csv',
#  'SARIG_Data_Package/sarig_md_reference_exp.csv',
#  'SARIG_Data_Package/sarig_md_zone_hr_lith_exp.csv',
#  'SARIG_Data_Package/sarig_md_zone_lith_exp.csv',
#  'SARIG_Data_Package/sarig_rs_biostr_analys_exp.csv',
#  'SARIG_Data_Package/sarig_rs_biostr_results_exp.csv',
#  'SARIG_Data_Package/sarig_rs_chem_exp.csv',
# ...

# %%
# """read the tables related to one dataset and process it."""

# # select the files to be opened as pandas DataFrame
# tables_to_read = ['SARIG_Data_Package/sarig_dh_core_exp.csv',
#  'SARIG_Data_Package/sarig_dh_details_exp.csv',
#  'SARIG_Data_Package/sarig_dh_litho_exp.csv',
#  'SARIG_Data_Package/sarig_dh_petrophys_exp.csv',
#  'SARIG_Data_Package/sarig_dh_reference_exp.csv',
#  'SARIG_Data_Package/sarig_dh_strat_exp.csv']

# for item in tables_to_read:
#     df_name = item.split('/')[-1].split('.')[0]
#     vars()[df_name] = pd.read_csv(
#         zipfile(os.path.join(data_loc, file_name),'r').open(item,'r'), sep=',', encoding='latin1')
#     print(vars()[df_name].head(5))

# %%
sarig_rs_biostr_analys_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_rs_biostr_analys_exp.csv','r'), 
    sep=',', encoding='latin1')
sarig_rs_biostr_analys_exp.head(10)
# Out:
#    SAMPLE_NO  SAMPLE_ANALYSIS_NO OTHER_SAMPLE_NO  DRILLHOLE_NO  \
# 0         26             1267025           S2493           NaN
# 1         27             1267026           S2494           NaN
# 2         54             1267027           S9587           NaN
# 3         55             1267028           S2588           NaN
# 4        169             1269295           S3201           NaN
# 5        984              265410            S595         260.0
# 6        999              265425            S631         257.0
# 7       1005              265206           S1232         266.0
# 8       1051              265180           S1121           NaN
# 9       1052              261923           S1335         273.0
#
#     DRILLHOLE_NAME  DEPTH_FROM  DEPTH_TO SAMPLE_SOURCE_CODE  \
# 0              NaN        0.88      0.92                 SF
# 1              NaN        1.36      1.38                 SF
# 2              NaN      380.00       NaN                 SF
# ...

# %%
sarig_rs_chem_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_rs_chem_exp.csv','r'), 
    sep=',', encoding='latin1', nrows= 100000)
sarig_rs_chem_exp.head(10)
# Out:
#    SAMPLE_NO SAMPLE_SOURCE_CODE         SAMPLE_SOURCE ROCK_GROUP_CODE  \
# 0        589                 RO  Rock outcrop / float             SSA
# 1        589                 RO  Rock outcrop / float             SSA
# 2        589                 RO  Rock outcrop / float             SSA
# 3        589                 RO  Rock outcrop / float             SSA
# 4        589                 RO  Rock outcrop / float             SSA
# 5        589                 RO  Rock outcrop / float             SSA
# 6        589                 RO  Rock outcrop / float             SSA
# 7        589                 RO  Rock outcrop / float             SSA
# 8        589                 RO  Rock outcrop / float             SSA
# 9        590                 RO  Rock outcrop / float             IMI
#
#                        ROCK_GROUP LITHO_CODE LITHO_CONF LITHOLOGY_NAME  \
# 0  Sediment Siliciclastic Arenite       SDST        NaN      Sandstone
# ...

# %%
sarig_rs_chem_exp[['SAMPLE_NO', 'SAMPLE_SOURCE_CODE', 'ROCK_GROUP_CODE', 'LITHO_CODE',
 'LITHO_MODIFIER', 'MAP_SYMBOL', 'STRAT_NAME', 'COLLECTED_DATE', 
 'DRILLHOLE_NUMBER', 'DH_DEPTH_FROM', 'DH_DEPTH_TO', 'SITE_NO', 
 'EASTING_GDA2020', 'NORTHING_GDA2020', 'ZONE_GDA2020', 'LONGITUDE_GDA2020',
 'LATITUDE_GDA2020', 'LONGITUDE_GDA94', 'LATITUDE_GDA94', 
 'SAMPLE_ANALYSIS_NO', 'OTHER_ANALYSIS_ID', 'CHEM_CODE', 'VALUE', 'UNIT',
 'CHEM_METHOD_CODE']].head(1500).stack()
# Out:
# 0     SAMPLE_NO                    589
#       SAMPLE_SOURCE_CODE            RO
#       ROCK_GROUP_CODE              SSA
#       LITHO_CODE                  SDST
#       COLLECTED_DATE        13/12/1960
#                                ...
# 1499  OTHER_ANALYSIS_ID        EX 3530
#       CHEM_CODE                     Tl
#       VALUE                        0.1
#       UNIT                         ppm
#       CHEM_METHOD_CODE        ARU25/MS
# Length: 25640, dtype: object

# %%
sarig_rs_biostr_results_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_rs_biostr_results_exp.csv','r'), 
    sep=',', encoding='latin1')
sarig_rs_biostr_results_exp.head()
# Out:
#    SAMPLE_NO  SAMPLE_ANALYSIS_NO ANALYSIS_TYPE        BIOSTRAT_RESULT  \
# 0      48625              655147  Foraminifera  Ammonia aff. beccarii
# 1       1999              265968       Mollusc       Ammonia beccarii
# 2     427140              261330  Foraminifera       Ammonia beccarii
# 3     427138              261328  Foraminifera       Ammonia beccarii
# 4     427137              261327  Foraminifera       Ammonia beccarii
#
#      BIOSTRAT_RESULT_TYPE TYPE_SPECIMEN FIGURED_SPECIMEN COMMENTS  SITE_NO  \
# 0  Benthonic Foraminifera             N                N      NaN   118730
# 1  Benthonic Foraminifera             N                N      NaN   129060
# 2  Benthonic Foraminifera             N                N      NaN    51024
# 3  Benthonic Foraminifera             N                N      NaN    51024
# 4  Benthonic Foraminifera             N                N      NaN    51024
#
#    EASTING_GDA2020  NORTHING_GDA2020  ZONE_GDA2020  LONGITUDE_GDA2020  \
# ...

# %%
sarig_rs_chem_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_rs_chem_exp.csv','r'), 
    sep=',', encoding='latin1', nrows=10000)
sarig_rs_chem_exp.head(20)
# Out:
#     SAMPLE_NO SAMPLE_SOURCE_CODE         SAMPLE_SOURCE ROCK_GROUP_CODE  \
# 0         589                 RO  Rock outcrop / float             SSA
# 1         589                 RO  Rock outcrop / float             SSA
# 2         589                 RO  Rock outcrop / float             SSA
# 3         589                 RO  Rock outcrop / float             SSA
# 4         589                 RO  Rock outcrop / float             SSA
# 5         589                 RO  Rock outcrop / float             SSA
# 6         589                 RO  Rock outcrop / float             SSA
# 7         589                 RO  Rock outcrop / float             SSA
# 8         589                 RO  Rock outcrop / float             SSA
# 9         590                 RO  Rock outcrop / float             IMI
# 10        590                 RO  Rock outcrop / float             IMI
# 11        589                 RO  Rock outcrop / float             SSA
# ...

# %%
sarig_rs_chem_exp.columns
# Out:
# Index(['SAMPLE_NO', 'SAMPLE_SOURCE_CODE', 'SAMPLE_SOURCE', 'ROCK_GROUP_CODE',
#        'ROCK_GROUP', 'LITHO_CODE', 'LITHO_CONF', 'LITHOLOGY_NAME',
#        'LITHO_MODIFIER', 'MAP_SYMBOL', 'STRAT_CONF', 'STRAT_NAME',
#        'COLLECTED_BY', 'COLLECTORS_NUMBER', 'COLLECTED_DATE',
#        'DRILLHOLE_NUMBER', 'DH_NAME', 'DH_DEPTH_FROM', 'DH_DEPTH_TO',
#        'SITE_NO', 'EASTING_GDA2020', 'NORTHING_GDA2020', 'ZONE_GDA2020',
#        'LONGITUDE_GDA2020', 'LATITUDE_GDA2020', 'LONGITUDE_GDA94',
#        'LATITUDE_GDA94', 'SAMPLE_ANALYSIS_NO', 'OTHER_ANALYSIS_ID',
#        'ANALYSIS_TYPE_DESC', 'LABORATORY', 'CHEM_CODE', 'VALUE', 'UNIT',
#        'CHEM_METHOD_CODE', 'CHEM_METHOD_DESC'],
#       dtype='object')

# %%
sarig_rs_chem_isotope_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_rs_chem_isotope_exp.csv','r'), 
    sep=',', encoding='latin1')
sarig_rs_chem_isotope_exp.head()
# Out:
#    SAMPLE_NO  SAMPLE_ANALYSIS_NO  OTHER_ANALYSIS_ID          ANALYSIS_TYPE  \
# 0    2017972             2022196                NaN  U-Pb Isotope Analysis
# 1    2017972             2022196                NaN  U-Pb Isotope Analysis
# 2    2017972             2022196                NaN  U-Pb Isotope Analysis
# 3    2017972             2022196                NaN  U-Pb Isotope Analysis
# 4    2017972             2022196                NaN  U-Pb Isotope Analysis
#
#                                     LABORATORY     ANALYST ANALYSIS_DATE  \
# 0  Adelaide Microscopy, University of Adelaide  REID, A.J.     18/MAR/15
# 1  Adelaide Microscopy, University of Adelaide  REID, A.J.     18/MAR/15
# 2  Adelaide Microscopy, University of Adelaide  REID, A.J.     18/MAR/15
# 3  Adelaide Microscopy, University of Adelaide  REID, A.J.     18/MAR/15
# 4  Adelaide Microscopy, University of Adelaide  REID, A.J.     18/MAR/15
#
#       SPECIMEN_TYPE MIN_SEPARATE_MINERAL STRATIGRAPHIC_UNIT  ...  \
# ...

# %%
sarig_rs_details_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_rs_details_exp.csv','r'), 
    sep=',', encoding='latin1', nrows = 10000)
sarig_rs_details_exp.head(5)
# Out:
#    SAMPLE_NO SAMPLE_SOURCE_CODE         SAMPLE_SOURCE ROCK_GROUP_CODE  \
# 0         21                NaN                   NaN             NaN
# 1         40                NaN                   NaN             NaN
# 2        477                 RO  Rock outcrop / float             III
# 3        488                 CT        Drill cuttings             NaN
# 4        489                 RO  Rock outcrop / float             SSA
#
#                        ROCK_GROUP LITHO_CODE LITHO_CONF LITHOLOGY_NAME  \
# 0                             NaN        NaN        NaN            NaN
# 1                             NaN        NaN        NaN            NaN
# 2  Igneous Intermediate Intrusive       MCDI        NaN   Microdiorite
# 3                             NaN        NaN        NaN            NaN
# 4  Sediment Siliciclastic Arenite       SDST        NaN      Sandstone
#
#   LITHO_MODIFIER MAP_SYMBOL  ... SITE_NO EASTING_GDA2020 NORTHING_GDA2020  \
# ...

# %%
sarig_rs_geochron_ages_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_rs_geochron_ages_exp.csv','r'), 
    sep=',', encoding='latin1')
sarig_rs_geochron_ages_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 31 columns):
# SAMPLE_NO                    35 non-null int64
# INTERPRETATION_NO            35 non-null int64
# INTERPRETATION_GROUP_NO      35 non-null int64
# INTERPRETOR                  35 non-null object
# INTERPRETATION_DATE          28 non-null object
# DATING_METHOD                35 non-null object
# AGE                          35 non-null int64
# AGE_UNIT                     35 non-null object
# AGE_ERROR_MIN                29 non-null float64
# AGE_ERROR_MAX                29 non-null float64
# AGE_ERROR_UNIT               29 non-null object
# GEOLOGICAL_ATTRIBUTION       35 non-null object
# AGE_TYPE                     35 non-null object
# ISOTOPE_RATIO_USED           0 non-null float64
# CORRECTION_FACTOR_APPLIED    0 non-null float64
# MSWD                         29 non-null float64
# PROBABILITY_OF_FIT           11 non-null float64
# ...

# %%
sarig_rs_geochron_reslt_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_rs_geochron_reslt_exp.csv','r'), 
    sep=',', encoding='latin1')

sarig_rs_geochron_reslt_exp.head(5)
# Out:
#    INTERPRETATION_NO  INTERPRETATION_GROUP_NO  SAMPLE_NO  SAMPLE_ANALYSIS_NO  \
# 0                  7                        7    2017961             2020330
# 1                  7                        7    2017961             2020330
# 2                  7                        7    2017961             2020330
# 3                  7                        7    2017961             2020330
# 4                  7                        7    2017961             2020330
#
#    OTHER_ANALYSIS_ID          ANALYSIS_TYPE  \
# 0                NaN  U-Pb Isotope Analysis
# 1                NaN  U-Pb Isotope Analysis
# 2                NaN  U-Pb Isotope Analysis
# 3                NaN  U-Pb Isotope Analysis
# 4                NaN  U-Pb Isotope Analysis
#
#                                     LABORATORY     ANALYST ANALYSIS_DATE  \
# 0  Adelaide Microscopy, University of Adelaide  REID, A.J.     20/MAR/14
# 1  Adelaide Microscopy, University of Adelaide  REID, A.J.     20/MAR/14
# ...

# %%
sarig_rs_petrology_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_rs_petrology_exp.csv','r'), 
    sep=',', encoding='latin1')
sarig_rs_petrology_exp.head(5)
# Out:
#    SAMPLE_NO  SAMPLE_ANALYSIS_NO THIN_SECTION_NO HISTORICAL_PETROLOGY_NO  \
# 0        588                 156             NaN                  P69/68
# 1        589                 157             NaN                 P928/60
# 2        590                 159             NaN                 P929/60
# 3        591                 161             NaN                 P930/60
# 4        611                 172             NaN                 P963/60
#
#   ROCK_TYPE_CODE ROCK_TYPE PETROLOGY_SUMMARY_DESC PETROLOGY_FULL_DESC  \
# 0            NaN       NaN                    NaN                 NaN
# 1            NaN       NaN                    NaN                 NaN
# 2            NaN       NaN                    NaN                 NaN
# 3            NaN       NaN                    NaN                 NaN
# 4            NaN       NaN                    NaN                 NaN
#
#   MINERALS_ABUNDANT MINERALS_MAJOR_ABUNDANCE  ... ANALYSIS_DATE  \
# ...

# %%
sarig_rs_reference_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_rs_reference_exp.csv','r'), 
    sep=',', encoding='latin1')
sarig_rs_reference_exp.head(5)
# Out:
# C:\Program Files\Python36\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    SAMPLE_NO      INFO_TYPE_DESC DOC_TYPE_DESC  REFERENCE          AUTHOR  \
# 0        487  Palaeontology Ref.   Report Book   RB 00731    Harris, W.K.
# 1        487  Palaeontology Ref.   Report Book   RB 00731  Ludbrook, N.H.
# 2        487         Master Ref.      Envelope  ENV 00645      Laws, R.A.
# 3        488         Master Ref.      Envelope  ENV 00645      Laws, R.A.
# 4        488  Palaeontology Ref.   Report Book   RB 00731    Harris, W.K.
#
#   PUBLICATION_DATE                                              TITLE  \
# 0        01/NOV/66  Outback Oil Hughes and Denman wells. Palynolog...
# 1        01/JAN/66  Hughes-Denman Stratigraphic Drilling Project o...
# ...

# %%
sarig_dh_core_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_dh_core_exp.csv','r'), 
    sep=',', encoding='latin1')
sarig_dh_core_exp.head(10), len(sarig_dh_core_exp)
# Out:
# (   DRILLHOLE_NO DRILLHOLE_NAME  TRAY_NO DUPLICATE_INTERVAL_SET  DEPTH_FROM_M  \
#  0            18            NaN        1                    NaN           0.0
#  1            20            NaN        1                    NaN           0.0
#  2            21           JR 2        1                    NaN           0.0
#  3            22            NaN        1                    NaN           0.0
#  4            23            NaN        1                    NaN           0.0
#  5            24            NaN        1                    NaN           0.0
#  6            25            NaN        1                    NaN           0.0
#  7            26            NaN        1                    NaN           0.0
#  8            29            NaN        1                    NaN           0.0
#  9            30            NaN        1                    NaN           0.0
#
#     DEPTH_TO_M  DEPTH_FROM_FEET  DEPTH_TO_FEET CORE_TYPE LIBRARY_LOCATION  ...  \
# ...

# %%
sarig_dh_core_exp = sarig_dh_core_exp[['DRILLHOLE_NO', 'TRAY_NO', 'DEPTH_FROM_M', 'DEPTH_TO_M',
                   'CORE_TYPE', 'ROCK_SAMPLE', 'GEOCHEMISTRY', 'PETROLOGY', 
                   'BIOSTRATIGRAPHY', 'STRAT_LOG_MAP_SYMBOLS', 'SITE_NO', 
                   'EASTING_GDA2020', 'NORTHING_GDA2020', 'ZONE_GDA2020', 
                   'LONGITUDE_GDA2020', 'LATITUDE_GDA2020', 'LONGITUDE_GDA94',
                   'LATITUDE_GDA94']]
sarig_dh_core_exp = sarig_dh_core_exp.drop_duplicates(subset=None, keep='first', inplace=False)

# %%
sarig_dh_core_exp.NORTHING_GDA2020.dtypes
# Out:
# dtype('float64')

# %%
for col in sarig_dh_core_exp.columns:
    if not sarig_dh_core_exp[col].dtypes in ['float64', 'int64']:
        print(col,'-----------\n', sarig_dh_core_exp[col].value_counts())
# Out:
# CORE_TYPE -----------
#  Core       172991
# Cutting     51744
# Name: CORE_TYPE, dtype: int64
# ROCK_SAMPLE -----------
#  N    148483
# Y     76252
# Name: ROCK_SAMPLE, dtype: int64
# GEOCHEMISTRY -----------
#  N    172488
# Y     52247
# Name: GEOCHEMISTRY, dtype: int64
# PETROLOGY -----------
#  N    216397
# Y      8338
# Name: PETROLOGY, dtype: int64
# BIOSTRATIGRAPHY -----------
#  N    222667
# Y      2068
# Name: BIOSTRATIGRAPHY, dtype: int64
# STRAT_LOG_MAP_SYMBOLS -----------
#  M-p                                              5665
# Nnt                                              3941
# Lw                                               2698
# Ma                                               2563
# Lxwd                                             2543
#                                                  ...
# ns, Mar2, Maf2                                      1
# Qh, T, Nds, mm                                      1
# K-c, Kam, K-um, JK-n, J-w, K-u, Kwa, J-a, Kaw       1
# ...

# %%
len(sarig_dh_core_exp)
# Out:
# 224735

# %%
sarig_dh_details_exp = pd.read_csv(
    zipfile(os.path.join(data_loc, file_name),'r').open('SARIG_Data_Package/sarig_dh_details_exp.csv','r'), 
    sep=',', encoding='latin1')
sarig_dh_details_exp.head(10)
# Out:
# C:\Program Files\Python36\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    DRILLHOLE_NO          DH_NAME DH_OTHER_NAME PACE_DH  PACE_ROUND_NO  \
# 0             1  GINGERAH HILL 1           NaN       N            NaN
# 1             2         BROOKE 1           NaN       N            NaN
# 2             3         SAHARA 1           NaN       N            NaN
# 3             4     NYALAYI 1/90           NaN       N            NaN
# 4             5       GAMBANGA 1           NaN       N            NaN
# 5             6              NaN           NaN       N            NaN
# 6             7     NYALAYI 2/90           NaN       N            NaN
# 7             8     NYALAYI 3/90           NaN       N            NaN
# 8             9    RAWLINNA BORE           NaN       N            NaN
# ...

# %%
sarig_dh_core_exp[['DRILLHOLE_NO', 'DRILLHOLE_NAME', 'TRAY_NO', 'DUPLICATE_INTERVAL_SET',
       'DEPTH_FROM_M', 'DEPTH_TO_M', 'DEPTH_FROM_FEET', 'DEPTH_TO_FEET',
       'CORE_TYPE', 'LIBRARY_LOCATION', 'ROCK_SAMPLE', 'ROCK_SAMPLE_LIBRARY',
       'GEOCHEMISTRY', 'PETROLOGY', 'BIOSTRATIGRAPHY', 'STRAT_LOG_MAP_SYMBOLS',
       'STRAT_LOG_STRAT_NAMES', 'SITE_NO', 'EASTING_GDA2020',
       'NORTHING_GDA2020', 'ZONE_GDA2020', 'LONGITUDE_GDA2020',
       'LATITUDE_GDA2020', 'LONGITUDE_GDA94', 'LATITUDE_GDA94']]
# Out:
# Index(['DRILLHOLE_NO', 'DRILLHOLE_NAME', 'TRAY_NO', 'DUPLICATE_INTERVAL_SET',
#        'DEPTH_FROM_M', 'DEPTH_TO_M', 'DEPTH_FROM_FEET', 'DEPTH_TO_FEET',
#        'CORE_TYPE', 'LIBRARY_LOCATION', 'ROCK_SAMPLE', 'ROCK_SAMPLE_LIBRARY',
#        'GEOCHEMISTRY', 'PETROLOGY', 'BIOSTRATIGRAPHY', 'STRAT_LOG_MAP_SYMBOLS',
#        'STRAT_LOG_STRAT_NAMES', 'SITE_NO', 'EASTING_GDA2020',
#        'NORTHING_GDA2020', 'ZONE_GDA2020', 'LONGITUDE_GDA2020',
#        'LATITUDE_GDA2020', 'LONGITUDE_GDA94', 'LATITUDE_GDA94'],
#       dtype='object')

# %%
for item in open_related_tables(tables_to_read, data_loc, file_name):
    print(item)
# Out:
# sarig_dh_core_exp
# C:\Program Files\Python36\lib\site-packages\IPython\core\interactiveshell.py:3254: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# sarig_dh_details_exp
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 78-79: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# Out:
# ['SARIG_Data_Package/sarig_dh_core_exp.csv',
#  'SARIG_Data_Package/sarig_dh_details_exp.csv',
#  'SARIG_Data_Package/sarig_dh_litho_exp.csv',
#  'SARIG_Data_Package/sarig_dh_petrophys_exp.csv',
#  'SARIG_Data_Package/sarig_dh_reference_exp.csv',
#  'SARIG_Data_Package/sarig_dh_strat_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_litho_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_note_exp.csv',
#  'SARIG_Data_Package/sarig_fieldobs_struct_exp.csv',
#  'SARIG_Data_Package/sarig_md_commodity_exp.csv',
#  'SARIG_Data_Package/sarig_md_details_exp.csv',
#  'SARIG_Data_Package/sarig_md_mineralogy_exp.csv',
#  'SARIG_Data_Package/sarig_md_reference_exp.csv',
#  'SARIG_Data_Package/sarig_md_zone_hr_lith_exp.csv',
#  'SARIG_Data_Package/sarig_md_zone_lith_exp.csv',
#  'SARIG_Data_Package/sarig_rs_biostr_analys_exp.csv',
#  'SARIG_Data_Package/sarig_rs_biostr_results_exp.csv',
#  'SARIG_Data_Package/sarig_rs_chem_exp.csv',
# ...
